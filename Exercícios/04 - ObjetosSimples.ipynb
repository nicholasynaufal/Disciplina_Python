# %% [markdown]
# # Exercício 01:

# %% [markdown]
# No paradigma de Programação Orientada a Objetos, o que é um Objeto?

# %% [markdown]
# R: Objeto é uma entidade, instância de classe, que representa algo do mundo real e possui atributos e métodos

# %% [markdown]
# # Exercício 02:

# %% [markdown]
# Em Python, o método com nome count() faz parte do objeto da classe  string. Este objeto possuí outros atributos e métodos. Qual o código que pode  ser usado para verificar se count() é um método também presente no objeto  da classe integer?

# %% [markdown]
# R: É uma entidade do mundo real ou um conceito abstrato que possui: Atributos ou Funções: São as características do objeto, que representam o estado ou as informações que ele mantém. Métodos: São as ações ou comportamentos que o objeto pode realizar. Eles são funções que operam sobre os atributos do objeto.

# %% [markdown]
# # Exercício 03:

# %% [markdown]
# Marque V para os nomes válidos e F para os nomes inválidos em Python:

# %% [markdown]
# (V) nome_objeto
# (F) 1_nome_objeto
# (F) #nome_objeto
# (F) Lambda
# (V) nome_lambda
# (V) lambda_nome
# (F) @_nome_objeto
# (F) Nome objeto
# (V) NOME_OBJETO
# (V) nome_Objeto
# (V) nomeLambda

# %% [markdown]
# # Exercício 04:

# %% [markdown]
# Para instanciar uma variável que recebe um valor inteiro, com o nome objeto_inteiro, como deve ser o código em Python?

# %%
objeto_inteiro = 42

# %% [markdown]
# # Exercício 05:

# %% [markdown]
# Para instanciar uma variável que recebe um valor decimal, com o nome objeto_decimal, como deve ser o código em Python?

# %%
objeto_decimal = 42.0

# %% [markdown]
# # Exercício 06:

# %% [markdown]
# Escreva a classe de objeto ideal para se representar cada uma das
# seguintes informações:
#
# (a) O número da casa em um endereço -> float
#
# (b) A data de nascimento de uma pessoa -> string
#
# (c) Se uma pessoa é diabética ou não -> Boolean
#
# (d) A altura de uma pessoa em metros -> float
#
# (e) O resultado da divisão de 5 por 2  -> float
#
# (f) O resultado da multiplicação de 2,5 por 2 -> float

# %% [markdown]
# # Exercício 07:

# %% [markdown]
# Identifique a classe de objeto em Python dos seguintes valores:
#
# (a) "9 de agosto de 1968" -> str
#
# (b) 1.3 -> float
#
# (c) False -> Boolean
#
# (d) -31 -> int
#
# (e) “?” -> str
#
# (f) ‘1979’ -> str

# %% [markdown]
# # Exercício 08:

# %% [markdown]
# Instancie variáveis das classes abaixo, recebendo qualquer valor, e
# retorne os resultados: string, float, booleano, inteiro

# %%
objeto_string = "Olá, mundo!"
objeto_string
# Out:
# 'Olá, mundo!'

# %%
objeto_float = 3.1415
objeto_float
# Out:
# 3.1415

# %%
objeto_booleano = True
objeto_booleano
# Out:
# True

# %%
objeto_inteiro = 1234
objeto_inteiro

# %% [markdown]
# # Exercício 09:

# %% [markdown]
# Escreva a classe de objeto ideal para se representar cada uma das
# seguintes informações:
#
# (a) O nome de um gene -> STR
#
# (b) O fold change (razão) de expressão de uma proteína em relação ao controle; -> FLOAT
#
# (c) Uma sequencia aminoacídica; -> STR
#
# (d) Classificar um gene como up ou down regulated; -> BOOLEAN
#
# (e) O número de genes classificados como up ou down regulated ->  INT

# %% [markdown]
# # Exercício 10:

# %% [markdown]
# Dado a variável abaixo, qual método pode ser utilizado para buscar o
# número de ocorrências da sequencia “AUG” presentes no objeto?

# %%
sequencia_gene = "ACTGGGUAUGAATTGCGCTTAGACTGGGUAUGAATTGCG"
sequencia_gene.count("AUG")
# Out:
# 2
